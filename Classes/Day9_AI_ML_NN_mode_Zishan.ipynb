# %% [markdown]
# <a href="https://colab.research.google.com/github/Krit-Barnwal/Summer-Ai-Ml/blob/main/Day9_AI_ML_NN_mode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(Xtrain,ytrain),(Xtest,ytest) = keras.datasets.mnist.load_data()
print(Xtrain.shape)
print(ytrain.shape)
print(Xtest.shape)
print(ytest.shape)

#data scaling
Xtrain=Xtrain/Xtrain.max()
Xtest=Xtest/Xtest.max()
print(len(np.unique(ytrain)))
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)
# 10

# %%
import numpy as np
for i in range(1,36+1,1):
  temp= np.random.randint(0,60000)
  im=Xtrain[temp,:,:]
  lab=ytrain[temp]
  plt.subplot(6,6,i)
  plt.imshow(im,cmap='gray')
  plt.axis('off')
  plt.title(lab)
plt.show()

# %%
#create an empty nn feed forward
nn_model= keras.Sequential()
nn_model.add(keras.layers.Flatten(input_shape=(Xtrain.shape[1],Xtrain.shape[2])))
nn_model.add(keras.layers.Dense(128,activation='relu')) #hidden layer1
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer2
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer3

nn_model.add(keras.layers.Dense(len(np.unique(ytrain)))) #output layer


#optimizer add
nn_model.compile(optimizer="SGD",loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
print(nn_model.summary())
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_6 (Flatten)         (None, 784)               0
#
#  dense_23 (Dense)            (None, 128)               100480
#
#  dense_24 (Dense)            (None, 256)               33024
#
#  dense_25 (Dense)            (None, 256)               65792
#
#  dense_26 (Dense)            (None, 10)                2570
#
# ...
# Total params: 201866 (788.54 KB)
# Trainable params: 201866 (788.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history=nn_model.fit(Xtrain,ytrain,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.6771 - accuracy: 0.8180
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2730 - accuracy: 0.9212
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2172 - accuracy: 0.9378
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1825 - accuracy: 0.9471
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1577 - accuracy: 0.9539
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1379 - accuracy: 0.9592
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1223 - accuracy: 0.9640
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1098 - accuracy: 0.9678
# Epoch 9/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0992 - accuracy: 0.9708
# Epoch 10/10
# ...

# %%
# visualize the training loss and acc
plt.figure(1,(4,2))
plt.plot(history.epoch,history.history['loss'],'--ko')
plt.grid('on')
plt.title('Training loss graph ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.figure(2,(4,2))
plt.plot(history.epoch,history.history['accuracy'],'--ko')
plt.grid('on')
plt.title('Training accuracy graph ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# evaluate the test data

[loss, acc] = nn_model.evaluate(Xtest,ytest)
print('Loss:',loss)
print("Testing Accuracy",acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0984 - accuracy: 0.9710
# Loss: 0.09836820513010025
# Testing Accuracy 0.9710000157356262

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(Xtrain,ytrain),(Xtest,ytest) = keras.datasets.fashion_mnist.load_data()
print(Xtrain.shape)
print(ytrain.shape)
print(Xtest.shape)
print(ytest.shape)

#data scaling
Xtrain=Xtrain/Xtrain.max()
Xtest=Xtest/Xtest.max()
print(len(np.unique(ytrain)))
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)
# 10

# %%
import numpy as np
for i in range(1,36+1,1):
  temp= np.random.randint(0,60000)
  im=Xtrain[temp,:,:]
  lab=ytrain[temp]
  plt.subplot(6,6,i)
  plt.imshow(im,cmap='gray')
  plt.axis('off')
  plt.title(lab)
plt.show()

# %%
#create an empty nn feed forward
nn_model= keras.Sequential()
nn_model.add(keras.layers.Flatten(input_shape=(Xtrain.shape[1],Xtrain.shape[2])))
nn_model.add(keras.layers.Dense(128,activation='relu')) #hidden layer1
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer2
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer3

nn_model.add(keras.layers.Dense(len(np.unique(ytrain)))) #output layer


#optimizer add
nn_model.compile(optimizer="SGD",loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
print(nn_model.summary())
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_7 (Flatten)         (None, 784)               0
#
#  dense_27 (Dense)            (None, 128)               100480
#
#  dense_28 (Dense)            (None, 256)               33024
#
#  dense_29 (Dense)            (None, 256)               65792
#
#  dense_30 (Dense)            (None, 10)                2570
#
# ...
# Total params: 201866 (788.54 KB)
# Trainable params: 201866 (788.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history=nn_model.fit(Xtrain,ytrain,epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3119 - accuracy: 0.8862
# Epoch 2/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3038 - accuracy: 0.8881
# Epoch 3/20
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2966 - accuracy: 0.8921
# Epoch 4/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2898 - accuracy: 0.8943
# Epoch 5/20
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2839 - accuracy: 0.8958
# Epoch 6/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2777 - accuracy: 0.8985
# Epoch 7/20
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2722 - accuracy: 0.8998
# Epoch 8/20
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2662 - accuracy: 0.9018
# Epoch 9/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2605 - accuracy: 0.9038
# Epoch 10/20
# ...

# %%
# visualize the training loss and acc
plt.figure(1,(4,2))
plt.plot(history.epoch,history.history['loss'],'--ko')
plt.grid('on')
plt.title('Training loss graph ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.figure(2,(4,2))
plt.plot(history.epoch,history.history['accuracy'],'--ko')
plt.grid('on')
plt.title('Training accuracy graph ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# evaluate the test data

[loss, acc] = nn_model.evaluate(Xtest,ytest)
print('Loss:',loss)
print("Testing Accuracy",acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3386 - accuracy: 0.8822
# Loss: 0.33856481313705444
# Testing Accuracy 0.8822000026702881

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

(Xtrain,ytrain),(Xtest,ytest) = keras.datasets.cifar10.load_data()
print(Xtrain.shape)
print(ytrain.shape)
print(Xtest.shape)
print(ytest.shape)

#data scaling
Xtrain=Xtrain/Xtrain.max()
Xtest=Xtest/Xtest.max()
print(len(np.unique(ytrain)))
# Out:
# ...
# 170498071/170498071 [==============================] - 4s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)
# 10

# %%
import numpy as np
for i in range(1,36+1,1):
  temp= np.random.randint(0,50000)
  im=Xtrain[temp,:,:]
  lab=ytrain[temp]
  plt.subplot(6,6,i)
  plt.imshow(im,cmap='gray')
  plt.axis('off')
  plt.title(lab)
plt.show()

# %%
#create an empty nn feed forward
nn_model= keras.Sequential()
nn_model.add(keras.layers.Flatten(input_shape=(Xtrain.shape[1],Xtrain.shape[2],Xtrain.shape[3])))
nn_model.add(keras.layers.Dense(128,activation='relu')) #hidden layer1
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer2
nn_model.add(keras.layers.Dense(256,activation='relu')) #hidden layer3

nn_model.add(keras.layers.Dense(len(np.unique(ytrain)))) #output layer


#optimizer add
nn_model.compile(optimizer="SGD",loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
print(nn_model.summary())
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_9 (Flatten)         (None, 3072)              0
#
#  dense_35 (Dense)            (None, 128)               393344
#
#  dense_36 (Dense)            (None, 256)               33024
#
#  dense_37 (Dense)            (None, 256)               65792
#
#  dense_38 (Dense)            (None, 10)                2570
#
# ...
# Total params: 494730 (1.89 MB)
# Trainable params: 494730 (1.89 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
history=nn_model.fit(Xtrain,ytrain,epochs=80)
# Out:
# Epoch 1/80
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.1435 - accuracy: 0.5952
# Epoch 2/80
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1337 - accuracy: 0.5985
# Epoch 3/80
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1163 - accuracy: 0.6044
# Epoch 4/80
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0989 - accuracy: 0.6105
# Epoch 5/80
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.0848 - accuracy: 0.6157
# Epoch 6/80
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.0714 - accuracy: 0.6192
# Epoch 7/80
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0585 - accuracy: 0.6253
# Epoch 8/80
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.0419 - accuracy: 0.6328
# Epoch 9/80
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0306 - accuracy: 0.6327
# Epoch 10/80
# ...

# %%
# visualize the training loss and acc
plt.figure(1,(4,2))
plt.plot(history.epoch,history.history['loss'],'--ko')
plt.grid('on')
plt.title('Training loss graph ')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.figure(2,(4,2))
plt.plot(history.epoch,history.history['accuracy'],'--ko')
plt.grid('on')
plt.title('Training accuracy graph ')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# evaluate the test data

[loss, acc] = nn_model.evaluate(Xtest,ytest)
print('Loss:',loss)
print("Testing Accuracy",acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1.3607 - accuracy: 0.5141
# Loss: 1.360672116279602
# Testing Accuracy 0.5141000151634216
